# %%
import Crafting_Item
import pandas as pd

# %%
Testing_Item = Crafting_Item.CraftingItem(96613)

test_dict = Testing_Item.get_analysis_metrics()
# Out:
# Profit margin for Jade Bot Core: Tier 10 is 5.1061 gold per item

# %%
Testing_Item.raw_ingredients

# %%
print(f"total calls is {Crafting_Item.call_tracker}")
print(f"total names is {Crafting_Item.call_tracker_name}")
print(f"total ids is {Crafting_Item.call_tracker_recipe_id}")
print(f"total recipes is {Crafting_Item.call_tracker_recipe_data}")
print(f"total prices is {Crafting_Item.call_tracker_price}")
# Out:
# total calls is 548
# total names is 45
# total ids is 446
# total recipes is 33
# total prices is 24

# %%
Testing_Item.base_ingredients

# %%
# %%
cores = list(Crafting_Item.HARDCODED_RECIPES.keys())

return_dict = {}

for core in cores:
    item = Crafting_Item.CraftingItem(core)

    return_dict[core] = item.get_analysis_metrics()
# Out:
# Profit margin for Jade Bot Core: Tier 1 is 0.521475 gold per item
# Profit margin for Jade Bot Core: Tier 2 is 1.7460949999999997 gold per item
# Profit margin for Jade Bot Core: Tier 3 is 3.9396949999999995 gold per item
# Profit margin for Jade Bot Core: Tier 4 is 4.1957949999999995 gold per item
# Profit margin for Jade Bot Core: Tier 5 is 5.003310000000001 gold per item
# Profit margin for Jade Bot Core: Tier 6 is 5.7932299999999985 gold per item
# Profit margin for Jade Bot Core: Tier 7 is 9.2655 gold per item
# Profit margin for Jade Bot Core: Tier 8 is 10.3841 gold per item
# Profit margin for Jade Bot Core: Tier 9 is 10.841445000000002 gold per item
# Profit margin for Jade Bot Core: Tier 10 is 5.1061 gold per item
# Profit margin for Piece of Dragon Jade is 0.3656 gold per item

# %%
# %%
return_dict

# %%
df = pd.DataFrame.from_dict(return_dict, orient='index')

df.head(11)
# Out:
#                     item_name  item_id  total_raw_resources  profit_margin  \
# 97339   Jade Bot Core: Tier 1    97339                 60.0       0.521475
# 97041   Jade Bot Core: Tier 2    97041                136.0       1.746095
# 97284   Jade Bot Core: Tier 3    97284                277.0       3.939695
# 96628   Jade Bot Core: Tier 4    96628                403.0       4.195795
# 95864   Jade Bot Core: Tier 5    95864                599.0       5.003310
# 96467   Jade Bot Core: Tier 6    96467                775.0       5.793230
# 97020   Jade Bot Core: Tier 7    97020               1001.0       9.265500
# 96299   Jade Bot Core: Tier 8    96299               1357.0      10.384100
# 96070   Jade Bot Core: Tier 9    96070               1773.0      10.841445
# 96613  Jade Bot Core: Tier 10    96613               2626.0       5.106100
# 97487    Piece of Dragon Jade    97487                 46.0       0.365600
#
#        profit_per_raw  crafting_cost  price_sell     gap_%  volume
# 97339        0.008691         1.1781      1.9995  0.193948    1654
# 97041        0.012839         2.4535      4.9407  0.412452     541
# 97284        0.014223         4.5524      9.9907  0.364129     210
# 96628        0.010411         5.9878     11.9807  0.333870     166
# 95864        0.008353         8.3762     15.7406  0.394483     143
# 96467        0.007475        10.3566     18.9998  0.220887     254
# 97020        0.009256        13.3870     26.6500  0.294098     108
# 96299        0.007652        16.6544     31.8100  0.239827     118
# 96070        0.006115        21.2118     37.7097  0.230376     174
# 96613        0.001944        29.6589     40.9000  0.049548     591
# 97487        0.007948         1.1134      1.7400  0.269310    5193
